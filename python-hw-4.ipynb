# %% [markdown]
# Вам нужно помочь секретарю автоматизировать работу. Для этого нужно написать программу, которая будет на основе хранимых данных исполнять пользовательские команды.
#
# Исходные данные имеют следующую структуру:
#
# перечень всех документов
# documents = [
#     {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
#     {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
#     {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
# ]
# перечень полок, на которых хранятся документы (если документ есть в documents, то он обязательно должен быть и в directories)
# directories = {
#     '1': ['2207 876234', '11-2'],
#     '2': ['10006'],
#     '3': []
# }
# Общие требования к программе:
#
# код должен быть грамотно декомпозирован (каждая функция отвечает за свою конкретную задачу, дублирующийся функционал переиспользуется, а его код не повторяется);
# в коде отсутствуют глобальные переменные (за исключением documents и directories);
# пользовательский ввод обрабатывается в цикле while до тех пор, пока пользователь явно не завершит программу (вводом команды "q").

# %% [markdown]
# Задание 1
#
# Пункт 1. Пользователь по команде "p" может узнать владельца документа по его номеру
# Пункт 2. Пользователь по команде "s" может по номеру документа узнать на какой полке он хранится
# Пункт 3. Пользователь по команде "l" может увидеть полную информацию по всем документам
# Пункт 4. Пользователь по команде "ads" может добавить новую полку
# Пункт 5. Пользователь по команде "ds" может удалить существующую полку из данных (только если она пустая)

# %%
### РЕШЕНИЕ 1 ЗАДАНИЯ

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

"""
выдает список number из documents
"""
num_docs = []
for i in range(len(documents)): num_docs.append(documents[i].get('number'))
#print(num_docs)

"""
выдает список с добавленной полкой
"""
for doc in documents: 
    for key in directories:
        if doc['number'] in directories[key]:
            doc['shelf'] = key
#print(documents)

"""
функция возвращает данные по номеру документа number в зависимости от команды command
"""
def number_analyse(command, number):
    if command == 'p':
        for i in range(len(documents)): 
            if number == documents[i].get('number'): result = documents[i].get('name')
    elif command == 's':
        for i in range(len(documents)): 
            if number == documents[i].get('number'): result = documents[i].get('shelf')
    return result

"""
функция работает со словарем, содержащим номера полок как ключи, и в зависимости от команды command и наличия/отсутствия номеров документов на полке
"""
def shelf_action(command, number):
    if command == 'ads': result = directories.setdefault(number, [])
    elif command == 'ds': result = directories.pop(number)
    return result

com = input('Введите команду:')
while com != 'q':
    '''
     блок обработки команд и номера документа
    '''
    if com == 'p' or com == 's': 
        num = input('Введите номер документа:')
        if num in num_docs and com == 'p': print(f'Владелец документа: '{number_analyse(com, num)})
        elif num in num_docs and com == 's': print(f'Документ хранится на полке:'{shelf_action(com, num)})
        else: print('Документ не найден в базе')
    elif com == '/': 
        for i in range(len(documents)): 
            for item in documents[i].items(): print(f'№: '{documents[i].get('number')} ', тип: '{documents[i].get('type')}', владелец: '{documents[i].get('name')}', полка хранения: '{documents[i].get('shelf')})
    '''
     блок работы с номерами полок
    '''
    elif com == 'ads' or com == 'ds': 
        num = input('Введите номер полки:')
        if num in list(directories.keys()): print(f'Такая полка уже существует. Текущий перечень полок:' {list(directories.keys())})
        elif com == 'ads': 
            shelf_action(com, num)
            print(f'Полка добавлена. Текущий перечень полок:' {list(directories.keys())})
        elif com == 'ds':
            if num in directories.keys():
                if directories[num] == []:
                    shelf_action(com, num)
                    print(f'Полка удалена. Текущий перечень полок:' {list(directories.keys())})
                else: print(f'На полке есть документа, удалите их перед удалением полки. Текущий перечень полок:' {list(directories.keys())})
            else: print(f'Такой полки не существует. Текущий перечень полок:' {list(directories.keys())})
    else: print('Неизвестная команда')

# %% [markdown]
# ### Тестовые блоки

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

"""
выдает список number из documents
"""
num_docs = []
for i in range(len(documents)): num_docs.append(documents[i].get('number'))
print(num_docs)

print(list(directories.keys()))
print((directories.values()))
print(list(directories))


def number_analyse(command, number):
    if command == 'p':
        for i in range(len(documents)): 
            if number == documents[i].get('number'): result = documents[i].get('name')
    return result

print(number_analyse('p', '10006'))

def shelf_action(command, number):
    if command == 'ads': result = directories.setdefault(number, [])
    return result
print(directories.keys(), shelf_action('ads', '16'))
# Out:
# ['2207 876234', '11-2', '10006']
# ['1', '2', '3']
# dict_values([['2207 876234', '11-2'], ['10006'], []])
# ['1', '2', '3']
# Аристарх Павлов
# dict_keys(['1', '2', '3', '16']) []

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}


"""
выдает список number
"""
num_docs = []
for i in range(len(documents)): num_docs.append(documents[i].get('number'))
print(num_docs)

"""
выдает список значений number-name
"""
num = []
for i in range(len(documents)): 
    for item in documents[i].items():
        num = documents[i].get('number')
        name = documents[i].get('name')
    print({'num': num, 'name': name})
"""
выдает словарь number-name
"""
num_name = {}
for i in range(len(documents)): 
    for item in documents[i].items():
        num_name['number'] = documents[i].get('number')
        num_name['name'] = documents[i].get('name')
    print(num_name)

"""
выдает список с добавленной полкой
"""
for doc in documents: 
    for key in directories:
        if doc['number'] in directories[key]:
            doc['shelf'] = key
print(documents)
# Out:
# ['2207 876234', '11-2', '10006']
# {'num': '2207 876234', 'name': 'Василий Гупкин'}
# {'num': '11-2', 'name': 'Геннадий Покемонов'}
# {'num': '10006', 'name': 'Аристарх Павлов'}
# {'number': '2207 876234', 'name': 'Василий Гупкин'}
# {'number': '11-2', 'name': 'Геннадий Покемонов'}
# {'number': '10006', 'name': 'Аристарх Павлов'}
# [{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин', 'shelf': '1'}, {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов', 'shelf': '1'}, {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов', 'shelf': '2'}]
